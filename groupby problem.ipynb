# %%
import pandas as pd

# %%
raw = pd.read_csv('Beni - mapped.csv')

# %%
xls.booth =xls.booth.astype(str)

# %%
xls.head()
# Out:
#   District_x   Taluka Village  # Applicants        Tehsil tag  \
# 0  Ratnagiri  CHIPLUN   Akale            51  RatnagiriCHIPLUN
# 1  Ratnagiri  CHIPLUN   ALORE            14  RatnagiriCHIPLUN
# 2  Ratnagiri  CHIPLUN   ALORE            14  RatnagiriCHIPLUN
# 3  Ratnagiri  CHIPLUN   ALORE            14  RatnagiriCHIPLUN
# 4  Ratnagiri  CHIPLUN   ALORE            14  RatnagiriCHIPLUN
#
#                      key tehsil Removal village removal  Final Tag  \
# 0  ratnagirichiplunakale              N               N        NaN
# 1  ratnagirichiplunalore              N               N        NaN
# 2  ratnagirichiplunalore              N               N        NaN
# 3  ratnagirichiplunalore              N               N        NaN
# 4  ratnagirichiplunalore              N               N        NaN
#
#   AC number_booth District_y  AC number  AC name  \
# 0          265_17  Ratnagiri        265  Chiplun
# 1         265_114  Ratnagiri        265  Chiplun
# ...

# %%
grouped = xls.groupby(['District_x', 'Taluka','Village','Tehsil tag','key','# Applicants'])

# %%
xls = pd.DataFrame(xls.groupby('key')['booth'].apply(','.join))

# %%
merger =
# Out:
#                            booth
# key
# akolaakolaagar       50,51,52,53
# akolaakolaakhatwada           93
# akolaakolaamanatpur           82
# akolaakolaambikapur           75
# akolaakolaanakwadi            92

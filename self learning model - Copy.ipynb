# %%
import pandas as pd

# %%
from PIL import Image

# %%
list234=[51,49,47,45,39,37,35]

# %%
import glob
for i in list234:
    str13=r'C:\Users\User\Desktop\sxxas\krAC-'+str(i)+'\*.pdf'
    interesting_files = glob.glob(str13,recursive= True )
    print(interesting_files)
# Out:
# ['C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-001.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-002.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-003.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-004.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-005.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-006.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-007.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-008.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-009.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-010.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-011.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-012.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-013.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-014.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-015.pdf', 'C:\\Users\\User\\Desktop\\sxxas\\krAC-51\\krAC-51-016.pdf', 'C:\\Users\\User\\Des
# ...

# %%
for ij in list234:
    import pandas as pd
    import glob
    str13=r'C:\Users\User\Desktop\sxxas\krAC-'+str(ij)+'\*.pdf'
    interesting_files = glob.glob(str13,recursive= True )
    from PIL import Image
    import pytesseract
    import cv2
    import codecs
    import pandas as pd
    from pdf2image import convert_from_path
    
    df = []
    for i in interesting_files:
    
        pages = convert_from_path(i, 500)
        pages[0].save('test.png')
        image = Image.open('test.png')
        left = 2385
        top = 2586
        right = 3877
        bottom = 3650
        image = image.crop((left, top, right, bottom))
        image.save('jj.png')
   

    # construct the argument parse and parse the arguments


    # load the example image and convert it to grayscale
        image = cv2.imread('jj.PNG')
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        cv2.imshow("Image", gray)
        gray = cv2.threshold(gray, 0, 255,
            cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

        cv2.imwrite('writen.png', gray)
        tessdata_dir_config =  r'--tessdata-dir "C:\Program Files (x86)\Tesseract-OCR\tessdata"'
        pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract.exe'
        text = pytesseract.image_to_string(Image.open('writen.png'),lang = 'hin',config = tessdata_dir_config)
        text = [text]
        text = text[0].split('\n')
        str_list = list(filter(None, text))
        repo = ['मुख्य ग्राम का नाम','डाकघर','पंचायत','प्रखंड','थाना','अनुमंडल','जिला','पिन']
        if len(str_list) != 16:
            for p in repo:
                for j in range(len(str_list)):
                    str_list[j]=str_list[j].replace(p,'')
            head  = repo
            rest = str_list
            try:
                df1 = pd.DataFrame(rest).T
                df1.columns = head
                df1['ac_booth'] = i
                df.append(df1)
            except: 
                pass
        else:
            head  = repo
            rest = str_list[8:]
            try:
                df1 = pd.DataFrame(rest).T
                df1.columns = head
                df1['ac_booth'] = i
                df.append(df1)
            except:
                pass
    try:
        full_df = pd.concat(df)
        str12='AC-'+str(ij)+'.xlsx'
        full_df.to_excel(str12)
    except:
        print('error')
        break

# %%
full_df = pd.concat(df)

# %%
full_df.to_excel('AC-61.xlsx')

# %%
from PIL import Image
import pytesseract
import cv2
import codecs
import pandas as pd
from pdf2image import convert_from_path
    
df = []
for i in interesting_files:
    
    pages = convert_from_path(i, 500)
    pages[0].save('test.png')
    image = Image.open('test.png')
    left = 2385
    top = 2586
    right = 3877
    bottom = 3650
    image = image.crop((left, top, right, bottom))
    image.save('jj.png')
   

    # construct the argument parse and parse the arguments


    # load the example image and convert it to grayscale
    image = cv2.imread('jj.PNG')
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imshow("Image", gray)
    gray = cv2.threshold(gray, 0, 255,
        cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

    cv2.imwrite('writen.png', gray)
    tessdata_dir_config =  r'--tessdata-dir "C:\Program Files (x86)\Tesseract-OCR\tessdata"'
    pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract.exe'
    text = pytesseract.image_to_string(Image.open('writen.png'),lang = 'hin',config = tessdata_dir_config)
    text = [text]
    text = text[0].split('\n')
    str_list = list(filter(None, text))
    repo = ['मुख्य ग्राम का नाम','डाकघर','पंचायत','प्रखंड','थाना','अनुमंडल','जिला','पिन']
    if len(str_list) != 16:
        for p in repo:
            for j in range(len(str_list)):
                str_list[j]=str_list[j].replace(p,'')
        head  = repo
        rest = str_list
        try:
            df1 = pd.DataFrame(rest).T
            df1.columns = head
            df1['ac_booth'] = i
            df.append(df1)
        except: 
            pass
    else:
        head  = repo
        rest = str_list[8:]
        try:
            df1 = pd.DataFrame(rest).T
            df1.columns = head
            df1['ac_booth'] = i
            df.append(df1)
        except:
            pass

# %%
str_list

# %%
for i in range(len(df)):
    r = pd.concat(df[i])

# %%
len(full_df)
# Out:
# 1896

# %%
full_df = pd.concat(df)

# %%
full_df.to_excel('full_71.xlsx')

# %%
from pdf2image import convert_from_path
pages = convert_from_path('krAC-76-003.pdf', 500)

# %%
pages[0].save('out.jpg')

# %%
image = Image.open('out.jpg')

# %%
left = 2385
top = 2586
right = 3877
bottom = 3650
image = image.crop((left, top, right, bottom))

# %%
image.save('jj.png')

# %%
# USAGE
# python ocr.py --image images/example_01.png 
# python ocr.py --image images/example_02.png  --preprocess blur

# import the necessary packages
from PIL import Image
import pytesseract
import cv2
import codecs
import pandas as pd

# construct the argument parse and parse the arguments


# load the example image and convert it to grayscale
image = cv2.imread('kk.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imshow("Image", gray)




# make a check to see if median blurring should be done to remove
# noise
gray = cv2.threshold(gray, 0, 255,
	cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

cv2.imwrite('writen.png', gray)
# write the grayscale image to disk as a temporary file so we can
# apply OCR to it


#load the image as a PIL/Pillow image, apply OCR, and then delete
# the temporary file
tessdata_dir_config =  r'--tessdata-dir "C:\Program Files (x86)\Tesseract-OCR\tessdata"'
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract.exe'
#proc=check_output('RunTess.bat').split()
text = pytesseract.image_to_string(Image.open('writen.png'),lang = 'eng',config = tessdata_dir_config)

print(text)

#text = pd.DataFrame(text)



# show the output images
# cv2.imshow("Image", image)

# %%
str_list = list(filter(None, text))

# %%
str_list

# %%
L = pd.DataFrame(str_list)

# %%
L.to_excel('pdd.xlsx')

# %%
255/7

# %%
rest = str_list[8:]

# %%
rest

# %%
repo = ['मुख्य ग्राम का नाम','डाकघर','पंचायत','प्रखंड','थाना','अनुमंडल','जिला','पिन']

# %%
for i in repo:
    for j in range(len(str_list)):
        str_list[j]=str_list[j].replace(i,'')
str_list

# %%
head  = repo
rest = str_list[8:]
df1 = pd.DataFrame(rest).T
df1.columns = head

# %%
df1

# %%
df1['ac_booth'] = name

# %%
x =df1

# %%
df1

# %%
x
